# %% [markdown]
# # Add src folder to Python path

# %%
import sys
import os
ROOT_DIR = os.path.realpath(os.path.join(os.path.abspath(''), '..'))
FOLDER_PATH = os.path.join(ROOT_DIR, "src/")
sys.path.append(FOLDER_PATH)

# %%
from app import Application
import pandas as pd
import numpy as np
import joblib
from pprint import pprint
from sklearn.model_selection import train_test_split, RandomizedSearchCV
from sklearn.feature_selection import SelectKBest, chi2
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

# %% [markdown]
# # Parameters
#
# This module fits an optimized Random forest classifier
# to predict a category of banking transaction.
# Data is loaded from the path and transformed to used format
# in the app.DataFrame.load_data(), which may be
# extended to accept new file types for your own purposes.
# The model will be saved into the current folder.

# %%
DATA_PATH           = "/Users/rasmus/Ohjelmointi/visual_studio/AI_finance/tools/testing_file.csv"
TRAINING_SPLIT      = 0.2
RANDOM_SEARCH_N     = 500
CROSS_VALIDATION    = 3
SAVE_MODEL          = True
MODEL_NAME          = "trained_test_model.pkl"

# %% [markdown]
# # Used dataset

# %%
app = Application()
df = app.data_frame
df.load_data(DATA_PATH)
print(df.get_info_str())
# Out:
# Local path: /Users/rasmus/Ohjelmointi/visual_studio/AI_finance/tools/testing_file.csv
# Data loaded from AIDF-file
# Used separator: (,) endoding: utf-8
#
# Shape of the DataFrame: (146, 4)
#          Date              Receiver  Amount   Category
# 0  2022-07-31          VR-YHTYMÄ OY  -49.90  COMMUTING
# 1  2022-07-28  DRESSMANN 707 KAMPPI  -19.95   CLOTHING
# 2  2022-07-28                   H&M  -19.99   CLOTHING
# 3  2022-07-27          VR-YHTYMÄ OY  -27.00  COMMUTING
# 4  2022-07-27     STOCKMANN TAPIOLA  -53.40   CLOTHING
# 5  2022-07-25            BESTSELLER  -79.99   CLOTHING
# 6  2022-07-25      NISSEN ISO OMENA   -7.90     HEALTH
# 7  2022-07-25      PRISMA ISO OMENA  -34.66       FOOD
# 8  2022-07-25          YA Iso Omena  -11.44     HEALTH
# 9  2022-07-25   ALEPA OTANIEMI UUSI  -14.56       FOOD
#
# Rows with NaNs:
# 0
#
# Rows with Empty strings:
# 2

# %% [markdown]
# # Dataset after removing nulls and empty strings

# %%
df.remove_empties()
print(df.get_info_str())
# Out:
# Local path: /Users/rasmus/Ohjelmointi/visual_studio/AI_finance/tools/testing_file.csv
# Data loaded from AIDF-file
# Used separator: (,) endoding: utf-8
#
# Shape of the DataFrame: (144, 4)
#          Date              Receiver  Amount   Category
# 0  2022-07-31          VR-YHTYMÄ OY  -49.90  COMMUTING
# 1  2022-07-28  DRESSMANN 707 KAMPPI  -19.95   CLOTHING
# 2  2022-07-28                   H&M  -19.99   CLOTHING
# 3  2022-07-27          VR-YHTYMÄ OY  -27.00  COMMUTING
# 4  2022-07-27     STOCKMANN TAPIOLA  -53.40   CLOTHING
# 5  2022-07-25            BESTSELLER  -79.99   CLOTHING
# 6  2022-07-25      NISSEN ISO OMENA   -7.90     HEALTH
# 7  2022-07-25      PRISMA ISO OMENA  -34.66       FOOD
# 8  2022-07-25          YA Iso Omena  -11.44     HEALTH
# 9  2022-07-25   ALEPA OTANIEMI UUSI  -14.56       FOOD
#
# Rows with NaNs:
# 0
#
# Rows with Empty strings:
# 0

# %% [markdown]
# # Splitting data into training and validation sets

# %%
dataset = df.get_df()
training_data = dataset.iloc[:, [1, 2]]
class_data = dataset.iloc[:, 3]
X_train, X_test, y_train, y_test = train_test_split(training_data, class_data, 
                                                    test_size=TRAINING_SPLIT, 
                                                    random_state=21, 
                                                    stratify=class_data)

print("Training X:" + str(X_train.shape) + " y:" + str(y_train.shape) + " (Rows, Columns)")
print("Testing  X:" + str(X_test.shape) + " y:" + str(y_test.shape) + " (Rows, Columns)")
print("\nHead of training X:")
print(X_train.head(5))
print("\nHead of training y:")
print(y_train.head(5))
print("\n\n\n\n")
# Out:
# Training X:(115, 2) y:(115,) (Rows, Columns)
# Testing  X:(29, 2) y:(29,) (Rows, Columns)
#
# Head of training X:
#                       Receiver  Amount
# 135           STARSHIP ESTONIA   -3.57
# 69   Bestseller AS JJ-VM_FI_40  -39.99
# 95   VFI*TMK Tori ja markkinak  -70.00
# 66              STADIUM OUTLET  -29.99
# 102                  SEO Jaala  -20.00
#
# Head of training y:
# 135               FOOD
# 69            CLOTHING
# 95     HOUSEHOLD ITEMS
# 66             HOBBIES
# 102          COMMUTING
# Name: Category, dtype: object

# %% [markdown]
# # Pipeline

# %%
'''
Text vectorizer
'''  
text_transformer = Pipeline(
    steps=[
       ('textVectorizer', CountVectorizer()),
       ('wordBankDimRed', SelectKBest(chi2, k='all'))
    ]
)
'''
Preprocessor of pipeline
'''
preprocessor = ColumnTransformer(
   transformers=[
       ('textTransformer', text_transformer, 0)
       
    ], remainder = 'passthrough'
) 
'''
Head of pipeline
'''
pipeline = Pipeline(
    steps=[
        ("preprocessor", preprocessor),
        ('randomForest', RandomForestClassifier())
    ]
)

# %% [markdown]
# # Fitting the model

# %%
# ======================= HYPERPARAMETERS TO BE TESTED ==========================
'''
Fitting functions tests randomly some of theses hyperparameters to find 
the best model. Changes can be made according to the "Best found parameters:"
''' 
n_estimators        = [int(x) for x in np.linspace(start = 1, stop = 120, num = 120)]
max_depth           = [int(x) for x in np.linspace(1, 50, num = 50)]
min_samples_split   = [int(x) for x in np.linspace(1, 20, num = 20)]
min_samples_leaf    = [int(x) for x in np.linspace(1, 10, num = 10)]
bootstrap           = [True, False]
chi2_k              = [int(x) for x in np.linspace(start = 50, stop = 200, num = 150)]


random_grid =  {'randomForest__n_estimators': n_estimators,
                'randomForest__max_depth': max_depth,
                'randomForest__min_samples_split': min_samples_split,
                'randomForest__min_samples_leaf': min_samples_leaf,
                'randomForest__bootstrap': bootstrap,
                'preprocessor__textTransformer__wordBankDimRed__k': chi2_k}


base_model = pipeline
base_model.fit(X_train, y_train)

tuned_model = RandomizedSearchCV(estimator=pipeline, 
                               param_distributions=random_grid, 
                               n_iter=RANDOM_SEARCH_N, 
                               cv=CROSS_VALIDATION, 
                               verbose=1, 
                               random_state=42, 
                               n_jobs =-1)

tuned_model.fit(X_train, y_train)
best_model = tuned_model.best_estimator_
print("\nBest found parameters:")
pprint(tuned_model.best_params_)
# Out:
# Fitting 3 folds for each of 500 candidates, totalling 1500 fits
# /Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/sklearn/model_selection/_split.py:684: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=3.
#   warnings.warn(
# Best found parameters:
# {'preprocessor__textTransformer__wordBankDimRed__k': 80,
#  'randomForest__bootstrap': False,
#  'randomForest__max_depth': 22,
#  'randomForest__min_samples_leaf': 1,
#  'randomForest__min_samples_split': 20,
#  'randomForest__n_estimators': 104}
# /Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:378: FitFailedWarning:
# 1072 fits failed out of a total of 1500.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 12 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/sklearn/pipeline.py", line 378, in fit
#     Xt = self._fit(X, y, **fit_params_steps)
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/sklearn/pipeline.py", line 336, in _fit
#     X, fitted_transformer = fit_transform_one_cached(
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/joblib/memory.py", line 349, in __call__
#     return self.func(*args, **kwargs)
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/sklearn/pipeline.py", line 870, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **fit_params)
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/sklearn/compose/_column_transformer.py", line 690, in fit_transform
#     result = self._fit_transform(X, y, _fit_transform_one)
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/sklearn/compose/_column_transformer.py", line 621, in _fit_transform
#     return Parallel(n_jobs=self.n_jobs)(
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/joblib/parallel.py", line 1085, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/joblib/parallel.py", line 901, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/joblib/parallel.py", line 819, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/joblib/_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/joblib/_parallel_backends.py", line 597, in __init__
#     self.results = batch()
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/joblib/parallel.py", line 288, in __call__
#     return [func(*args, **kwargs)
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/joblib/parallel.py", line 288, in <listcomp>
#     return [func(*args, **kwargs)
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/sklearn/utils/fixes.py", line 117, in __call__
#     return self.function(*args, **kwargs)
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/sklearn/pipeline.py", line 870, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **fit_params)
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/sklearn/pipeline.py", line 422, in fit_transform
#     return last_step.fit_transform(Xt, y, **fit_params_last_step)
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/sklearn/base.py", line 870, in fit_transform
#     return self.fit(X, y, **fit_params).transform(X)
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/sklearn/feature_selection/_univariate_selection.py", line 471, in fit
#     self._check_params(X, y)
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/sklearn/feature_selection/_univariate_selection.py", line 668, in _check_params
#     raise ValueError(
# ValueError: k should be >=0, <= n_features = 93; got 133. Use k='all' to return all features.
#
# --------------------------------------------------------------------------------
# 6 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/sklearn/pipeline.py", line 378, in fit
#     Xt = self._fit(X, y, **fit_params_steps)
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/sklearn/pipeline.py", line 336, in _fit
#     X, fitted_transformer = fit_transform_one_cached(
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/joblib/memory.py", line 349, in __call__
#     return self.func(*args, **kwargs)
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/sklearn/pipeline.py", line 870, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **fit_params)
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/sklearn/compose/_column_transformer.py", line 690, in fit_transform
#     result = self._fit_transform(X, y, _fit_transform_one)
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/sklearn/compose/_column_transformer.py", line 621, in _fit_transform
#     return Parallel(n_jobs=self.n_jobs)(
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/joblib/parallel.py", line 1085, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/joblib/parallel.py", line 901, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/joblib/parallel.py", line 819, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/joblib/_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/joblib/_parallel_backends.py", line 597, in __init__
#     self.results = batch()
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/joblib/parallel.py", line 288, in __call__
#     return [func(*args, **kwargs)
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/joblib/parallel.py", line 288, in <listcomp>
#     return [func(*args, **kwargs)
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/sklearn/utils/fixes.py", line 117, in __call__
#     return self.function(*args, **kwargs)
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/sklearn/pipeline.py", line 870, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **fit_params)
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/sklearn/pipeline.py", line 422, in fit_transform
#     return last_step.fit_transform(Xt, y, **fit_params_last_step)
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/sklearn/base.py", line 870, in fit_transform
#     return self.fit(X, y, **fit_params).transform(X)
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/sklearn/feature_selection/_univariate_selection.py", line 471, in fit
#     self._check_params(X, y)
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/sklearn/feature_selection/_univariate_selection.py", line 668, in _check_params
#     raise ValueError(
# ValueError: k should be >=0, <= n_features = 89; got 133. Use k='all' to return all features.
#
# --------------------------------------------------------------------------------
# 8 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/sklearn/pipeline.py", line 378, in fit
#     Xt = self._fit(X, y, **fit_params_steps)
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/sklearn/pipeline.py", line 336, in _fit
#     X, fitted_transformer = fit_transform_one_cached(
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/joblib/memory.py", line 349, in __call__
#     return self.func(*args, **kwargs)
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/sklearn/pipeline.py", line 870, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **fit_params)
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/sklearn/compose/_column_transformer.py", line 690, in fit_transform
#     result = self._fit_transform(X, y, _fit_transform_one)
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/sklearn/compose/_column_transformer.py", line 621, in _fit_transform
#     return Parallel(n_jobs=self.n_jobs)(
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/joblib/parallel.py", line 1085, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/joblib/parallel.py", line 901, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/joblib/parallel.py", line 819, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/joblib/_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/joblib/_parallel_backends.py", line 597, in __init__
#     self.results = batch()
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/joblib/parallel.py", line 288, in __call__
#     return [func(*args, **kwargs)
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/joblib/parallel.py", line 288, in <listcomp>
#     return [func(*args, **kwargs)
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/sklearn/utils/fixes.py", line 117, in __call__
#     return self.function(*args, **kwargs)
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/sklearn/pipeline.py", line 870, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **fit_params)
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/sklearn/pipeline.py", line 422, in fit_transform
#     return last_step.fit_transform(Xt, y, **fit_params_last_step)
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/sklearn/base.py", line 870, in fit_transform
#     return self.fit(X, y, **fit_params).transform(X)
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/sklearn/feature_selection/_univariate_selection.py", line 471, in fit
#     self._check_params(X, y)
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/sklearn/feature_selection/_univariate_selection.py", line 668, in _check_params
#     raise ValueError(
# ValueError: k should be >=0, <= n_features = 93; got 185. Use k='all' to return all features.
#
# --------------------------------------------------------------------------------
# 4 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/sklearn/pipeline.py", line 378, in fit
#     Xt = self._fit(X, y, **fit_params_steps)
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/sklearn/pipeline.py", line 336, in _fit
#     X, fitted_transformer = fit_transform_one_cached(
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/joblib/memory.py", line 349, in __call__
#     return self.func(*args, **kwargs)
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/sklearn/pipeline.py", line 870, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **fit_params)
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/sklearn/compose/_column_transformer.py", line 690, in fit_transform
#     result = self._fit_transform(X, y, _fit_transform_one)
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/sklearn/compose/_column_transformer.py", line 621, in _fit_transform
#     return Parallel(n_jobs=self.n_jobs)(
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/joblib/parallel.py", line 1085, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/joblib/parallel.py", line 901, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/joblib/parallel.py", line 819, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/joblib/_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/joblib/_parallel_backends.py", line 597, in __init__
#     self.results = batch()
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/joblib/parallel.py", line 288, in __call__
#     return [func(*args, **kwargs)
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/joblib/parallel.py", line 288, in <listcomp>
#     return [func(*args, **kwargs)
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/sklearn/utils/fixes.py", line 117, in __call__
#     return self.function(*args, **kwargs)
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/sklearn/pipeline.py", line 870, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **fit_params)
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/sklearn/pipeline.py", line 422, in fit_transform
#     return last_step.fit_transform(Xt, y, **fit_params_last_step)
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/sklearn/base.py", line 870, in fit_transform
#     return self.fit(X, y, **fit_params).transform(X)
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/sklearn/feature_selection/_univariate_selection.py", line 471, in fit
#     self._check_params(X, y)
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/sklearn/feature_selection/_univariate_selection.py", line 668, in _check_params
#     raise ValueError(
# ValueError: k should be >=0, <= n_features = 89; got 185. Use k='all' to return all features.
#
# --------------------------------------------------------------------------------
# 18 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/sklearn/pipeline.py", line 378, in fit
#     Xt = self._fit(X, y, **fit_params_steps)
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/sklearn/pipeline.py", line 336, in _fit
#     X, fitted_transformer = fit_transform_one_cached(
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/joblib/memory.py", line 349, in __call__
#     return self.func(*args, **kwargs)
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/sklearn/pipeline.py", line 870, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **fit_params)
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/sklearn/compose/_column_transformer.py", line 690, in fit_transform
#     result = self._fit_transform(X, y, _fit_transform_one)
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/sklearn/compose/_column_transformer.py", line 621, in _fit_transform
#     return Parallel(n_jobs=self.n_jobs)(
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/joblib/parallel.py", line 1085, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/joblib/parallel.py", line 901, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/joblib/parallel.py", line 819, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/joblib/_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/joblib/_parallel_backends.py", line 597, in __init__
#     self.results = batch()
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/joblib/parallel.py", line 288, in __call__
#     return [func(*args, **kwargs)
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/joblib/parallel.py", line 288, in <listcomp>
#     return [func(*args, **kwargs)
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/sklearn/utils/fixes.py", line 117, in __call__
#     return self.function(*args, **kwargs)
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/sklearn/pipeline.py", line 870, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **fit_params)
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/sklearn/pipeline.py", line 422, in fit_transform
#     return last_step.fit_transform(Xt, y, **fit_params_last_step)
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/sklearn/base.py", line 870, in fit_transform
#     return self.fit(X, y, **fit_params).transform(X)
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/sklearn/feature_selection/_univariate_selection.py", line 471, in fit
#     self._check_params(X, y)
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/sklearn/feature_selection/_univariate_selection.py", line 668, in _check_params
#     raise ValueError(
# ValueError: k should be >=0, <= n_features = 93; got 154. Use k='all' to return all features.
#
# --------------------------------------------------------------------------------
# 9 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/sklearn/pipeline.py", line 378, in fit
#     Xt = self._fit(X, y, **fit_params_steps)
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/sklearn/pipeline.py", line 336, in _fit
#     X, fitted_transformer = fit_transform_one_cached(
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/joblib/memory.py", line 349, in __call__
#     return self.func(*args, **kwargs)
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/sklearn/pipeline.py", line 870, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **fit_params)
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/sklearn/compose/_column_transformer.py", line 690, in fit_transform
#     result = self._fit_transform(X, y, _fit_transform_one)
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/sklearn/compose/_column_transformer.py", line 621, in _fit_transform
#     return Parallel(n_jobs=self.n_jobs)(
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/joblib/parallel.py", line 1085, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/joblib/parallel.py", line 901, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/joblib/parallel.py", line 819, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/joblib/_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/joblib/_parallel_backends.py", line 597, in __init__
#     self.results = batch()
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/joblib/parallel.py", line 288, in __call__
#     return [func(*args, **kwargs)
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/joblib/parallel.py", line 288, in <listcomp>
#     return [func(*args, **kwargs)
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/sklearn/utils/fixes.py", line 117, in __call__
#     return self.function(*args, **kwargs)
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/sklearn/pipeline.py", line 870, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **fit_params)
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/sklearn/pipeline.py", line 422, in fit_transform
#     return last_step.fit_transform(Xt, y, **fit_params_last_step)
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/sklearn/base.py", line 870, in fit_transform
#     return self.fit(X, y, **fit_params).transform(X)
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/sklearn/feature_selection/_univariate_selection.py", line 471, in fit
#     self._check_params(X, y)
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/sklearn/feature_selection/_univariate_selection.py", line 668, in _check_params
#     raise ValueError(
# ValueError: k should be >=0, <= n_features = 89; got 154. Use k='all' to return all features.
#
# --------------------------------------------------------------------------------
# 10 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/sklearn/pipeline.py", line 378, in fit
#     Xt = self._fit(X, y, **fit_params_steps)
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/sklearn/pipeline.py", line 336, in _fit
#     X, fitted_transformer = fit_transform_one_cached(
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/joblib/memory.py", line 349, in __call__
#     return self.func(*args, **kwargs)
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/sklearn/pipeline.py", line 870, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **fit_params)
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/sklearn/compose/_column_transformer.py", line 690, in fit_transform
#     result = self._fit_transform(X, y, _fit_transform_one)
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/sklearn/compose/_column_transformer.py", line 621, in _fit_transform
#     return Parallel(n_jobs=self.n_jobs)(
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/joblib/parallel.py", line 1085, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/joblib/parallel.py", line 901, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/joblib/parallel.py", line 819, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/joblib/_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/joblib/_parallel_backends.py", line 597, in __init__
#     self.results = batch()
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/joblib/parallel.py", line 288, in __call__
#     return [func(*args, **kwargs)
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/joblib/parallel.py", line 288, in <listcomp>
#     return [func(*args, **kwargs)
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/sklearn/utils/fixes.py", line 117, in __call__
#     return self.function(*args, **kwargs)
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/sklearn/pipeline.py", line 870, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **fit_params)
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/sklearn/pipeline.py", line 422, in fit_transform
#     return last_step.fit_transform(Xt, y, **fit_params_last_step)
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/sklearn/base.py", line 870, in fit_transform
#     return self.fit(X, y, **fit_params).transform(X)
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/sklearn/feature_selection/_univariate_selection.py", line 471, in fit
#     self._check_params(X, y)
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/sklearn/feature_selection/_univariate_selection.py", line 668, in _check_params
#     raise ValueError(
# ValueError: k should be >=0, <= n_features = 93; got 103. Use k='all' to return all features.
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/sklearn/pipeline.py", line 378, in fit
#     Xt = self._fit(X, y, **fit_params_steps)
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/sklearn/pipeline.py", line 336, in _fit
#     X, fitted_transformer = fit_transform_one_cached(
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/joblib/memory.py", line 349, in __call__
#     return self.func(*args, **kwargs)
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/sklearn/pipeline.py", line 870, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **fit_params)
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/sklearn/compose/_column_transformer.py", line 690, in fit_transform
#     result = self._fit_transform(X, y, _fit_transform_one)
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/sklearn/compose/_column_transformer.py", line 621, in _fit_transform
#     return Parallel(n_jobs=self.n_jobs)(
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/joblib/parallel.py", line 1085, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/joblib/parallel.py", line 901, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/joblib/parallel.py", line 819, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/joblib/_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/joblib/_parallel_backends.py", line 597, in __init__
#     self.results = batch()
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/joblib/parallel.py", line 288, in __call__
#     return [func(*args, **kwargs)
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/joblib/parallel.py", line 288, in <listcomp>
#     return [func(*args, **kwargs)
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/sklearn/utils/fixes.py", line 117, in __call__
#     return self.function(*args, **kwargs)
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/sklearn/pipeline.py", line 870, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **fit_params)
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/sklearn/pipeline.py", line 422, in fit_transform
#     return last_step.fit_transform(Xt, y, **fit_params_last_step)
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/sklearn/base.py", line 870, in fit_transform
#     return self.fit(X, y, **fit_params).transform(X)
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/sklearn/feature_selection/_univariate_selection.py", line 471, in fit
#     self._check_params(X, y)
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/sklearn/feature_selection/_univariate_selection.py", line 668, in _check_params
#     raise ValueError(
# ValueError: k should be >=0, <= n_features = 89; got 103. Use k='all' to return all features.
#
# --------------------------------------------------------------------------------
# 12 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/sklearn/pipeline.py", line 378, in fit
#     Xt = self._fit(X, y, **fit_params_steps)
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/sklearn/pipeline.py", line 336, in _fit
#     X, fitted_transformer = fit_transform_one_cached(
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/joblib/memory.py", line 349, in __call__
#     return self.func(*args, **kwargs)
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/sklearn/pipeline.py", line 870, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **fit_params)
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/sklearn/compose/_column_transformer.py", line 690, in fit_transform
#     result = self._fit_transform(X, y, _fit_transform_one)
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/sklearn/compose/_column_transformer.py", line 621, in _fit_transform
#     return Parallel(n_jobs=self.n_jobs)(
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/joblib/parallel.py", line 1085, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/joblib/parallel.py", line 901, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/joblib/parallel.py", line 819, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/joblib/_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/joblib/_parallel_backends.py", line 597, in __init__
#     self.results = batch()
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/joblib/parallel.py", line 288, in __call__
#     return [func(*args, **kwargs)
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/joblib/parallel.py", line 288, in <listcomp>
#     return [func(*args, **kwargs)
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/sklearn/utils/fixes.py", line 117, in __call__
#     return self.function(*args, **kwargs)
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/sklearn/pipeline.py", line 870, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **fit_params)
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/sklearn/pipeline.py", line 422, in fit_transform
#     return last_step.fit_transform(Xt, y, **fit_params_last_step)
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/sklearn/base.py", line 870, in fit_transform
#     return self.fit(X, y, **fit_params).transform(X)
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/sklearn/feature_selection/_univariate_selection.py", line 471, in fit
#     self._check_params(X, y)
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/sklearn/feature_selection/_univariate_selection.py", line 668, in _check_params
#     raise ValueError(
# ValueError: k should be >=0, <= n_features = 93; got 105. Use k='all' to return all features.
#
# --------------------------------------------------------------------------------
# 6 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/sklearn/pipeline.py", line 378, in fit
#     Xt = self._fit(X, y, **fit_params_steps)
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/sklearn/pipeline.py", line 336, in _fit
#     X, fitted_transformer = fit_transform_one_cached(
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/joblib/memory.py", line 349, in __call__
#     return self.func(*args, **kwargs)
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/sklearn/pipeline.py", line 870, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **fit_params)
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/sklearn/compose/_column_transformer.py", line 690, in fit_transform
#     result = self._fit_transform(X, y, _fit_transform_one)
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/sklearn/compose/_column_transformer.py", line 621, in _fit_transform
#     return Parallel(n_jobs=self.n_jobs)(
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/joblib/parallel.py", line 1085, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/joblib/parallel.py", line 901, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/joblib/parallel.py", line 819, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/joblib/_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/joblib/_parallel_backends.py", line 597, in __init__
#     self.results = batch()
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/joblib/parallel.py", line 288, in __call__
#     return [func(*args, **kwargs)
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/joblib/parallel.py", line 288, in <listcomp>
#     return [func(*args, **kwargs)
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/sklearn/utils/fixes.py", line 117, in __call__
#     return self.function(*args, **kwargs)
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/sklearn/pipeline.py", line 870, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **fit_params)
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/sklearn/pipeline.py", line 422, in fit_transform
#     return last_step.fit_transform(Xt, y, **fit_params_last_step)
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/sklearn/base.py", line 870, in fit_transform
#     return self.fit(X, y, **fit_params).transform(X)
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/sklearn/feature_selection/_univariate_selection.py", line 471, in fit
#     self._check_params(X, y)
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/sklearn/feature_selection/_univariate_selection.py", line 668, in _check_params
#     raise ValueError(
# ValueError: k should be >=0, <= n_features = 89; got 105. Use k='all' to return all features.
#
# --------------------------------------------------------------------------------
# 24 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/sklearn/pipeline.py", line 378, in fit
#     Xt = self._fit(X, y, **fit_params_steps)
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/sklearn/pipeline.py", line 336, in _fit
#     X, fitted_transformer = fit_transform_one_cached(
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/joblib/memory.py", line 349, in __call__
#     return self.func(*args, **kwargs)
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/sklearn/pipeline.py", line 870, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **fit_params)
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/sklearn/compose/_column_transformer.py", line 690, in fit_transform
#     result = self._fit_transform(X, y, _fit_transform_one)
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/sklearn/compose/_column_transformer.py", line 621, in _fit_transform
#     return Parallel(n_jobs=self.n_jobs)(
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/joblib/parallel.py", line 1085, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/joblib/parallel.py", line 901, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/joblib/parallel.py", line 819, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/joblib/_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/joblib/_parallel_backends.py", line 597, in __init__
#     self.results = batch()
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/joblib/parallel.py", line 288, in __call__
#     return [func(*args, **kwargs)
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/joblib/parallel.py", line 288, in <listcomp>
#     return [func(*args, **kwargs)
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/sklearn/utils/fixes.py", line 117, in __call__
#     return self.function(*args, **kwargs)
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/sklearn/pipeline.py", line 870, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **fit_params)
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/sklearn/pipeline.py", line 422, in fit_transform
#     return last_step.fit_transform(Xt, y, **fit_params_last_step)
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/sklearn/base.py", line 870, in fit_transform
#     return self.fit(X, y, **fit_params).transform(X)
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/sklearn/feature_selection/_univariate_selection.py", line 471, in fit
#     self._check_params(X, y)
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/sklearn/feature_selection/_univariate_selection.py", line 668, in _check_params
#     raise ValueError(
# ValueError: k should be >=0, <= n_features = 93; got 176. Use k='all' to return all features.
#
# --------------------------------------------------------------------------------
# 12 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/sklearn/pipeline.py", line 378, in fit
#     Xt = self._fit(X, y, **fit_params_steps)
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/sklearn/pipeline.py", line 336, in _fit
#     X, fitted_transformer = fit_transform_one_cached(
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/joblib/memory.py", line 349, in __call__
#     return self.func(*args, **kwargs)
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/sklearn/pipeline.py", line 870, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **fit_params)
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/sklearn/compose/_column_transformer.py", line 690, in fit_transform
#     result = self._fit_transform(X, y, _fit_transform_one)
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/sklearn/compose/_column_transformer.py", line 621, in _fit_transform
#     return Parallel(n_jobs=self.n_jobs)(
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/joblib/parallel.py", line 1085, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/joblib/parallel.py", line 901, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/joblib/parallel.py", line 819, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/joblib/_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/joblib/_parallel_backends.py", line 597, in __init__
#     self.results = batch()
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/joblib/parallel.py", line 288, in __call__
#     return [func(*args, **kwargs)
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/joblib/parallel.py", line 288, in <listcomp>
#     return [func(*args, **kwargs)
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/sklearn/utils/fixes.py", line 117, in __call__
#     return self.function(*args, **kwargs)
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/sklearn/pipeline.py", line 870, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **fit_params)
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/sklearn/pipeline.py", line 422, in fit_transform
#     return last_step.fit_transform(Xt, y, **fit_params_last_step)
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/sklearn/base.py", line 870, in fit_transform
#     return self.fit(X, y, **fit_params).transform(X)
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/sklearn/feature_selection/_univariate_selection.py", line 471, in fit
#     self._check_params(X, y)
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/sklearn/feature_selection/_univariate_selection.py", line 668, in _check_params
#     raise ValueError(
# ValueError: k should be >=0, <= n_features = 89; got 176. Use k='all' to return all features.
#
# --------------------------------------------------------------------------------
# 8 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/sklearn/pipeline.py", line 378, in fit
# ...
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/joblib/parallel.py", line 1085, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/joblib/parallel.py", line 901, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/joblib/parallel.py", line 819, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/joblib/_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/joblib/_parallel_backends.py", line 597, in __init__
#     self.results = batch()
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/joblib/parallel.py", line 288, in __call__
#     return [func(*args, **kwargs)
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/joblib/parallel.py", line 288, in <listcomp>
#     return [func(*args, **kwargs)
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/sklearn/utils/fixes.py", line 117, in __call__
#     return self.function(*args, **kwargs)
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/sklearn/pipeline.py", line 870, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **fit_params)
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/sklearn/pipeline.py", line 422, in fit_transform
#     return last_step.fit_transform(Xt, y, **fit_params_last_step)
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/sklearn/base.py", line 870, in fit_transform
#     return self.fit(X, y, **fit_params).transform(X)
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/sklearn/feature_selection/_univariate_selection.py", line 471, in fit
#     self._check_params(X, y)
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/sklearn/feature_selection/_univariate_selection.py", line 668, in _check_params
#     raise ValueError(
# ValueError: k should be >=0, <= n_features = 89; got 155. Use k='all' to return all features.
#
# --------------------------------------------------------------------------------
# 4 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/sklearn/pipeline.py", line 378, in fit
#     Xt = self._fit(X, y, **fit_params_steps)
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/sklearn/pipeline.py", line 336, in _fit
#     X, fitted_transformer = fit_transform_one_cached(
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/joblib/memory.py", line 349, in __call__
#     return self.func(*args, **kwargs)
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/sklearn/pipeline.py", line 870, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **fit_params)
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/sklearn/compose/_column_transformer.py", line 690, in fit_transform
#     result = self._fit_transform(X, y, _fit_transform_one)
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/sklearn/compose/_column_transformer.py", line 621, in _fit_transform
#     return Parallel(n_jobs=self.n_jobs)(
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/joblib/parallel.py", line 1085, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/joblib/parallel.py", line 901, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/joblib/parallel.py", line 819, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/joblib/_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/joblib/_parallel_backends.py", line 597, in __init__
#     self.results = batch()
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/joblib/parallel.py", line 288, in __call__
#     return [func(*args, **kwargs)
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/joblib/parallel.py", line 288, in <listcomp>
#     return [func(*args, **kwargs)
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/sklearn/utils/fixes.py", line 117, in __call__
#     return self.function(*args, **kwargs)
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/sklearn/pipeline.py", line 870, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **fit_params)
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/sklearn/pipeline.py", line 422, in fit_transform
#     return last_step.fit_transform(Xt, y, **fit_params_last_step)
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/sklearn/base.py", line 870, in fit_transform
#     return self.fit(X, y, **fit_params).transform(X)
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/sklearn/feature_selection/_univariate_selection.py", line 471, in fit
#     self._check_params(X, y)
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/sklearn/feature_selection/_univariate_selection.py", line 668, in _check_params
#     raise ValueError(
# ValueError: k should be >=0, <= n_features = 93; got 97. Use k='all' to return all features.
#
# --------------------------------------------------------------------------------
# 2 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/sklearn/pipeline.py", line 378, in fit
#     Xt = self._fit(X, y, **fit_params_steps)
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/sklearn/pipeline.py", line 336, in _fit
#     X, fitted_transformer = fit_transform_one_cached(
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/joblib/memory.py", line 349, in __call__
#     return self.func(*args, **kwargs)
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/sklearn/pipeline.py", line 870, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **fit_params)
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/sklearn/compose/_column_transformer.py", line 690, in fit_transform
#     result = self._fit_transform(X, y, _fit_transform_one)
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/sklearn/compose/_column_transformer.py", line 621, in _fit_transform
#     return Parallel(n_jobs=self.n_jobs)(
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/joblib/parallel.py", line 1085, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/joblib/parallel.py", line 901, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/joblib/parallel.py", line 819, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/joblib/_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/joblib/_parallel_backends.py", line 597, in __init__
#     self.results = batch()
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/joblib/parallel.py", line 288, in __call__
#     return [func(*args, **kwargs)
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/joblib/parallel.py", line 288, in <listcomp>
#     return [func(*args, **kwargs)
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/sklearn/utils/fixes.py", line 117, in __call__
#     return self.function(*args, **kwargs)
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/sklearn/pipeline.py", line 870, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **fit_params)
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/sklearn/pipeline.py", line 422, in fit_transform
#     return last_step.fit_transform(Xt, y, **fit_params_last_step)
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/sklearn/base.py", line 870, in fit_transform
#     return self.fit(X, y, **fit_params).transform(X)
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/sklearn/feature_selection/_univariate_selection.py", line 471, in fit
#     self._check_params(X, y)
#   File "/Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/sklearn/feature_selection/_univariate_selection.py", line 668, in _check_params
#     raise ValueError(
# ValueError: k should be >=0, <= n_features = 89; got 97. Use k='all' to return all features.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# /Users/rasmus/opt/miniconda3/envs/ai_finance_x86/lib/python3.9/site-packages/sklearn/model_selection/_search.py:953: UserWarning: One or more of the test scores are non-finite: [       nan        nan        nan        nan        nan        nan
#         nan        nan        nan 0.50449843        nan        nan
#  0.37381916        nan        nan        nan 0.44354476        nan
#         nan        nan        nan 0.37381916        nan        nan
#         nan        nan        nan 0.37381916        nan        nan
#         nan        nan        nan 0.37381916 0.3911381         nan
#         nan        nan        nan        nan 0.37381916        nan
#         nan        nan        nan 0.64349978        nan 0.53036437
#         nan        nan        nan        nan        nan        nan
#         nan 0.63472785 0.54790823        nan        nan 0.40845704
#         nan        nan 0.50449843        nan        nan        nan
#         nan        nan        nan        nan        nan 0.62640576
#  0.47818264        nan        nan        nan        nan        nan
#  0.37381916        nan        nan 0.37381916 0.37381916        nan
#         nan        nan        nan        nan 0.37381916        nan
#         nan        nan        nan 0.55668016        nan 0.37381916
#  0.37381916        nan        nan 0.55668016 0.37381916        nan
#         nan        nan        nan 0.37381916        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan 0.4957265         nan 0.37381916
#         nan 0.37381916 0.80004498        nan 0.51282051 0.37381916
#         nan        nan        nan        nan        nan        nan
#         nan 0.37381916 0.37381916        nan        nan 0.37381916
#         nan        nan 0.37381916        nan        nan 0.39091318
#         nan        nan        nan        nan        nan        nan
#  0.37381916        nan        nan        nan 0.37381916        nan
#         nan        nan        nan 0.46963563 0.37381916        nan
#         nan        nan 0.40845704        nan        nan 0.39136302
#         nan        nan 0.60053981        nan        nan 0.57377418
#         nan        nan        nan        nan        nan 0.37381916
#         nan        nan        nan 0.37381916        nan        nan
#         nan        nan 0.37381916 0.37381916        nan        nan
#         nan        nan        nan 0.51327036 0.40845704        nan
#         nan        nan        nan        nan 0.40845704        nan
#  0.48695457        nan        nan        nan        nan        nan
#  0.40845704        nan 0.37381916 0.37381916        nan        nan
#         nan        nan        nan        nan 0.5391363         nan
#         nan        nan        nan        nan 0.37381916 0.66036887
#         nan 0.74741341        nan        nan        nan        nan
#  0.39091318 0.37381916        nan 0.37381916        nan        nan
#         nan 0.37381916        nan 0.4957265         nan        nan
#         nan        nan 0.6871345         nan 0.37381916 0.37381916
#         nan        nan 0.37381916 0.37381916        nan        nan
#         nan 0.37381916 0.37381916        nan        nan 0.55668016
#  0.37381916        nan        nan        nan        nan        nan
#         nan 0.37381916        nan        nan 0.37381916        nan
#         nan        nan        nan        nan        nan        nan
#         nan 0.37381916        nan        nan        nan        nan
#         nan        nan        nan 0.50449843 0.817139   0.37381916
#  0.37381916 0.37381916 0.37381916        nan 0.37381916        nan
#         nan 0.37381916 0.37381916        nan        nan        nan
#         nan        nan        nan 0.39136302 0.37381916        nan
#         nan        nan        nan        nan        nan 0.80859199
#  0.8340081         nan        nan        nan        nan        nan
#         nan        nan        nan        nan 0.64327485        nan
#         nan        nan        nan        nan 0.37381916        nan
#         nan        nan        nan        nan        nan 0.4957265
#  0.5739991  0.56545209        nan 0.37381916        nan        nan
#  0.37381916        nan        nan        nan        nan        nan
#         nan        nan 0.37381916        nan        nan        nan
#  0.37381916 0.4957265  0.37381916        nan        nan        nan
#         nan        nan 0.50449843        nan        nan 0.50449843
#  0.37381916        nan 0.39136302        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan 0.37381916        nan        nan        nan        nan
#         nan 0.37381916        nan 0.37381916        nan 0.37381916
#  0.54790823        nan        nan        nan        nan        nan
#         nan        nan 0.37381916 0.37381916 0.83423302 0.79982006
#         nan        nan        nan        nan 0.77350427        nan
#         nan        nan 0.37381916        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan 0.37381916        nan        nan
#         nan        nan        nan 0.37381916        nan 0.37381916
#         nan        nan        nan        nan        nan        nan
#         nan 0.53013945 0.37381916        nan        nan        nan
#         nan        nan 0.84300495 0.37381916        nan        nan
#         nan        nan        nan        nan        nan 0.39968511
#  0.54790823        nan 0.36504723 0.37381916 0.37381916        nan
#  0.5391363  0.79037337        nan        nan        nan        nan
#         nan        nan        nan        nan        nan 0.37381916
#         nan        nan        nan        nan 0.37381916        nan
#  0.37381916 0.37381916        nan        nan        nan        nan
#         nan 0.62550607 0.37381916        nan        nan        nan
#         nan        nan]
#   warnings.warn(

# %% [markdown]
# # Validating classifier

# %%
def evaluate(model, test_features, test_labels):
    y_pred = model.predict(test_features)
    print(pd.crosstab(test_labels, y_pred, rownames=['Actual\u2193'], colnames=['Predicted\u2192']))
    accuracy = accuracy_score(test_labels, y_pred) 
    print('\nAccuracy {:0.2f}%.'.format(100*accuracy))
    return accuracy


print("Base model:")
base_accuracy = evaluate(base_model, X_test, y_test)

print("\nTuned model:")
random_accuracy = evaluate(best_model, X_test, y_test)

print('\nImprovement of {:0.2f}%.'.format( 100 * (random_accuracy - base_accuracy) / base_accuracy))
# Out:
# Base model:
# Predicted→     CLOTHING  COMMUTING  ENTERTAINMENT  FOOD  HEALTH  HOBBIES  \
# Actual↓
# CLOTHING              3          0              0     0       0        0
# COMMUTING             0          4              0     0       0        0
# ENTERTAINMENT         0          0              3     0       0        0
# FOOD                  0          0              0    11       0        0
# HEALTH                0          0              0     0       2        0
# HOBBIES               0          0              0     0       0        3
# TECHNOLOGY            0          0              0     0       0        0
#
# Predicted→     TECHNOLOGY
# Actual↓
# CLOTHING                0
# COMMUTING               0
# ENTERTAINMENT           0
# FOOD                    0
# HEALTH                  0
# HOBBIES                 0
# TECHNOLOGY              3
#
# Accuracy 100.00%.
#
# Tuned model:
# Predicted→     CLOTHING  COMMUTING  ENTERTAINMENT  FOOD  HEALTH  HOBBIES  \
# Actual↓
# CLOTHING              1          0              0     2       0        0
# COMMUTING             0          3              0     1       0        0
# ENTERTAINMENT         0          0              2     1       0        0
# FOOD                  0          0              0    11       0        0
# HEALTH                0          0              0     0       2        0
# HOBBIES               0          0              0     1       0        2
# TECHNOLOGY            0          0              0     0       0        0
#
# Predicted→     TECHNOLOGY
# Actual↓
# CLOTHING                0
# COMMUTING               0
# ENTERTAINMENT           0
# FOOD                    0
# HEALTH                  0
# HOBBIES                 0
# TECHNOLOGY              3
#
# Accuracy 82.76%.
#
# Improvement of -17.24%.

# %% [markdown]
# # Save the model

# %%
if SAVE_MODEL:
    with open(MODEL_NAME , 'wb') as file:
        joblib.dump(best_model, file)
        print("\nModel saved as: " + MODEL_NAME + " to current folder")
# Out:
# Model saved as: trained_test_model.pkl to current folder
